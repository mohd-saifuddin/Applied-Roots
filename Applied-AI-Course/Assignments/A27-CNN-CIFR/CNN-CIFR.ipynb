# %% [markdown]
# 1.  Please visit this link to access the state-of-art DenseNet code for reference - DenseNet - cifar10 notebook link
# 2.  You need to create a copy of this and "retrain" this model to achieve 90+ test accuracy.
# 3.  You cannot use DropOut layers.
# 4.  You MUST use Image Augmentation Techniques.
# 5.  You cannot use an already trained model as a beginning points, you have to initilize as your own
# 6.  You cannot run the program for more than 300 Epochs, and it should be clear from your log, that you have only used 300 Epochs
# 7.  You cannot use test images for training the model.
# 8.  You cannot change the general architecture of DenseNet (which means you must use Dense Block, Transition and Output blocks as mentioned in the code)
# 9.  You are free to change Convolution types (e.g. from 3x3 normal convolution to Depthwise Separable, etc)
# 10. You cannot have more than 1 Million parameters in total
# 11. You are free to move the code from Keras to Tensorflow, Pytorch, MXNET etc.
# 12. You can use any optimization algorithm you need.
# 13. You can checkpoint your model and retrain the model from that checkpoint so that no need of training the model from first if you lost at any epoch while training. You can directly load that model and Train from that epoch.

# %%
from tensorflow.keras.layers import (
    Flatten, 
    Dense, 
    Dropout, 
    concatenate, 
    Conv2D, 
    Input, 
    BatchNormalization, 
    ReLU, 
    AveragePooling2D, 
    MaxPool2D, 
    GlobalAveragePooling2D
)

from tensorflow.keras.callbacks import (
    EarlyStopping, 
    TensorBoard, 
    ModelCheckpoint, 
    Callback
)

from tensorflow.keras.models import Sequential, Model

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from matplotlib import pyplot as plt

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
import numpy as np
import datetime
import os

# %% [markdown]
# Data

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
image_shape = X_train.shape[1:]
print(image_shape)
# Out:
# (32, 32, 3)

# %%
num_classes = len(np.unique(y_train[:, 0]))
print(num_classes)
# Out:
# 10

# %%
y_train = to_categorical(y=y_train, num_classes=num_classes)
y_test = to_categorical(y=y_test, num_classes=num_classes)
print(y_train.shape, y_test.shape)
# Out:
# (50000, 10) (10000, 10)

# %% [markdown]
# Image generator

# %% [markdown]
# Reference: https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/

# %%
X_train_image_generator = ImageDataGenerator(rotation_range=15,
                                             horizontal_flip=True,
                                             width_shift_range=0.1,
                                             height_shift_range=0.1,
                                             rescale=1./255).flow(x=X_train, y=y_train)

# %%
X_test_image_generator = ImageDataGenerator(rotation_range=15,
                                            horizontal_flip=True,
                                            width_shift_range=0.1,
                                            height_shift_range=0.1,
                                            rescale=1./255).flow(x=X_test, y=y_test)

# %% [markdown]
# DenseNet
#
# Video: https://youtu.be/QKtoh9FJIWQ
#
# Code: https://github.com/Machine-Learning-Tokyo/DL-workshop-series/blob/master/Part%20I%20-%20Convolution%20Operations/ConvNets.ipynb

# %%
tf.keras.backend.clear_session()

# %%
def dense_net(image_shape, num_classes, filters=12):
    """
    DenseNet
    """

    def bn_rl_conv(x, f, k=1, s=1, p='same'):
        """
        Dense and Transition block helper.
        """
        x = BatchNormalization()(x)
        x = ReLU()(x)
        x = Conv2D(filters=f, kernel_size=k, strides=s, padding=p)(x)
        return x
    
    def dense_block(tensor, repetitions=36):
        """
        Dense block.
        """
        for _ in range(repetitions):
            x = bn_rl_conv(x=tensor, f=filters//2, k=3)
            tensor = concatenate(inputs=[tensor, x])
        return tensor
    
    def transition_block(x):
        """
        Transition block.
        """
        x = bn_rl_conv(x=x, f=filters//2, k=2)
        x = AveragePooling2D(strides=2, padding='same')(x)
        return x
    
    def output(x):
        """
        Output
        """
        x = BatchNormalization()(x)
        x = ReLU()(x)
        x = AveragePooling2D(strides=2, padding='same')(x)
        x = Flatten()(x)
        x = Dense(units=num_classes, activation='softmax')(x)
        return x
    
    input_layer = Input(shape=image_shape)
    x = Conv2D(filters=filters, kernel_size=3, use_bias=False, padding='same')(input_layer)
    
    d1 = dense_block(tensor=x)
    t1 = transition_block(x=d1)

    d2 = dense_block(tensor=t1)
    t2 = transition_block(x=d2)

    d3 = dense_block(tensor=t2)
    t3 = transition_block(x=d3)

    d4 = dense_block(tensor=t3)

    output_layer = output(x=d4)

    model = Model(inputs=input_layer, outputs=output_layer)
    return model

# %%
model = dense_net(image_shape=image_shape, num_classes=num_classes, filters=12)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 12)   324         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 12)  48          ['conv2d[0][0]']
#  alization)
#
#  re_lu (ReLU)                   (None, 32, 32, 12)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 6)    654         ['re_lu[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 18)   0           ['conv2d[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 18)  72          ['concatenate[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 32, 32, 18)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 6)    978         ['re_lu_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 24)   0           ['concatenate[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 24)  96          ['concatenate_1[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 32, 32, 24)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 6)    1302        ['re_lu_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 30)   0           ['concatenate_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 30)  120         ['concatenate_2[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 32, 32, 30)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 6)    1626        ['re_lu_3[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 36)   0           ['concatenate_2[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 36)  144         ['concatenate_3[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 32, 32, 36)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 6)    1950        ['re_lu_4[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 42)   0           ['concatenate_3[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 42)  168         ['concatenate_4[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 32, 32, 42)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 6)    2274        ['re_lu_5[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 48)   0           ['concatenate_4[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 48)  192         ['concatenate_5[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 32, 32, 48)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 6)    2598        ['re_lu_6[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 32, 32, 54)   0           ['concatenate_5[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 54)  216         ['concatenate_6[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 32, 32, 54)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 6)    2922        ['re_lu_7[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 32, 32, 60)   0           ['concatenate_6[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 60)  240         ['concatenate_7[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 32, 32, 60)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 6)    3246        ['re_lu_8[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 32, 32, 66)   0           ['concatenate_7[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 66)  264         ['concatenate_8[0][0]']
#  rmalization)
#
#  re_lu_9 (ReLU)                 (None, 32, 32, 66)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 6)    3570        ['re_lu_9[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 32, 32, 72)   0           ['concatenate_8[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 72)  288         ['concatenate_9[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 32, 32, 72)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 6)    3894        ['re_lu_10[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 32, 32, 78)   0           ['concatenate_9[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 78)  312         ['concatenate_10[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 32, 32, 78)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 6)    4218        ['re_lu_11[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 32, 32, 84)   0           ['concatenate_10[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 84)  336         ['concatenate_11[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 32, 32, 84)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 6)    4542        ['re_lu_12[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 32, 32, 90)   0           ['concatenate_11[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 90)  360         ['concatenate_12[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 32, 32, 90)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 6)    4866        ['re_lu_13[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 32, 32, 96)   0           ['concatenate_12[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 96)  384         ['concatenate_13[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 32, 32, 96)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 6)    5190        ['re_lu_14[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 32, 32, 102)  0           ['concatenate_13[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 102)  408        ['concatenate_14[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 32, 32, 102)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 6)    5514        ['re_lu_15[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 32, 32, 108)  0           ['concatenate_14[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 108)  432        ['concatenate_15[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 32, 32, 108)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 6)    5838        ['re_lu_16[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 32, 32, 114)  0           ['concatenate_15[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 114)  456        ['concatenate_16[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 32, 32, 114)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 6)    6162        ['re_lu_17[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 32, 32, 120)  0           ['concatenate_16[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 120)  480        ['concatenate_17[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 32, 32, 120)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 6)    6486        ['re_lu_18[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 32, 32, 126)  0           ['concatenate_17[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 126)  504        ['concatenate_18[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 32, 32, 126)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 6)    6810        ['re_lu_19[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 32, 32, 132)  0           ['concatenate_18[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 132)  528        ['concatenate_19[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 32, 32, 132)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 6)    7134        ['re_lu_20[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 32, 32, 138)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 32, 32, 138)  552        ['concatenate_20[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 32, 32, 138)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 6)    7458        ['re_lu_21[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 32, 32, 144)  0           ['concatenate_20[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 144)  576        ['concatenate_21[0][0]']
#  ormalization)
#
#  re_lu_22 (ReLU)                (None, 32, 32, 144)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 6)    7782        ['re_lu_22[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 32, 32, 150)  0           ['concatenate_21[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 150)  600        ['concatenate_22[0][0]']
#  ormalization)
#
#  re_lu_23 (ReLU)                (None, 32, 32, 150)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 6)    8106        ['re_lu_23[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 32, 32, 156)  0           ['concatenate_22[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 156)  624        ['concatenate_23[0][0]']
#  ormalization)
#
#  re_lu_24 (ReLU)                (None, 32, 32, 156)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 6)    8430        ['re_lu_24[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 32, 32, 162)  0           ['concatenate_23[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 162)  648        ['concatenate_24[0][0]']
#  ormalization)
#
#  re_lu_25 (ReLU)                (None, 32, 32, 162)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 6)    8754        ['re_lu_25[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 32, 32, 168)  0           ['concatenate_24[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 168)  672        ['concatenate_25[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 32, 32, 168)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 6)    9078        ['re_lu_26[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 32, 32, 174)  0           ['concatenate_25[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 174)  696        ['concatenate_26[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 32, 32, 174)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 6)    9402        ['re_lu_27[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 32, 32, 180)  0           ['concatenate_26[0][0]',
#                                                                   'conv2d_28[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 180)  720        ['concatenate_27[0][0]']
#  ormalization)
#
#  re_lu_28 (ReLU)                (None, 32, 32, 180)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 6)    9726        ['re_lu_28[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 32, 32, 186)  0           ['concatenate_27[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 186)  744        ['concatenate_28[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 32, 32, 186)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 6)    10050       ['re_lu_29[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 32, 32, 192)  0           ['concatenate_28[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 192)  768        ['concatenate_29[0][0]']
#  ormalization)
#
#  re_lu_30 (ReLU)                (None, 32, 32, 192)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 6)    10374       ['re_lu_30[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 32, 32, 198)  0           ['concatenate_29[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 198)  792        ['concatenate_30[0][0]']
#  ormalization)
#
#  re_lu_31 (ReLU)                (None, 32, 32, 198)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 6)    10698       ['re_lu_31[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 32, 32, 204)  0           ['concatenate_30[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 204)  816        ['concatenate_31[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 32, 32, 204)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 32, 32, 6)    11022       ['re_lu_32[0][0]']
#
#  concatenate_32 (Concatenate)   (None, 32, 32, 210)  0           ['concatenate_31[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 32, 32, 210)  840        ['concatenate_32[0][0]']
#  ormalization)
#
#  re_lu_33 (ReLU)                (None, 32, 32, 210)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 6)    11346       ['re_lu_33[0][0]']
#
#  concatenate_33 (Concatenate)   (None, 32, 32, 216)  0           ['concatenate_32[0][0]',
#                                                                   'conv2d_34[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 32, 32, 216)  864        ['concatenate_33[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 32, 32, 216)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 6)    11670       ['re_lu_34[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 32, 32, 222)  0           ['concatenate_33[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 32, 32, 222)  888        ['concatenate_34[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 32, 32, 222)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 6)    11994       ['re_lu_35[0][0]']
#
#  concatenate_35 (Concatenate)   (None, 32, 32, 228)  0           ['concatenate_34[0][0]',
#                                                                   'conv2d_36[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 32, 32, 228)  912        ['concatenate_35[0][0]']
#  ormalization)
#
#  re_lu_36 (ReLU)                (None, 32, 32, 228)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 6)    5478        ['re_lu_36[0][0]']
#
#  average_pooling2d (AveragePool  (None, 16, 16, 6)   0           ['conv2d_37[0][0]']
#  ing2D)
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 6)   24          ['average_pooling2d[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 16, 16, 6)    0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 6)    330         ['re_lu_37[0][0]']
#
#  concatenate_36 (Concatenate)   (None, 16, 16, 12)   0           ['average_pooling2d[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 16, 16, 12)  48          ['concatenate_36[0][0]']
#  ormalization)
#
#  re_lu_38 (ReLU)                (None, 16, 16, 12)   0           ['batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 16, 16, 6)    654         ['re_lu_38[0][0]']
#
#  concatenate_37 (Concatenate)   (None, 16, 16, 18)   0           ['concatenate_36[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 16, 16, 18)  72          ['concatenate_37[0][0]']
#  ormalization)
#
#  re_lu_39 (ReLU)                (None, 16, 16, 18)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 16, 16, 6)    978         ['re_lu_39[0][0]']
#
#  concatenate_38 (Concatenate)   (None, 16, 16, 24)   0           ['concatenate_37[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 16, 16, 24)  96          ['concatenate_38[0][0]']
#  ormalization)
#
#  re_lu_40 (ReLU)                (None, 16, 16, 24)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 6)    1302        ['re_lu_40[0][0]']
#
#  concatenate_39 (Concatenate)   (None, 16, 16, 30)   0           ['concatenate_38[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 16, 16, 30)  120         ['concatenate_39[0][0]']
#  ormalization)
#
#  re_lu_41 (ReLU)                (None, 16, 16, 30)   0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 6)    1626        ['re_lu_41[0][0]']
#
#  concatenate_40 (Concatenate)   (None, 16, 16, 36)   0           ['concatenate_39[0][0]',
#                                                                   'conv2d_42[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 36)  144         ['concatenate_40[0][0]']
#  ormalization)
#
#  re_lu_42 (ReLU)                (None, 16, 16, 36)   0           ['batch_normalization_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 6)    1950        ['re_lu_42[0][0]']
#
#  concatenate_41 (Concatenate)   (None, 16, 16, 42)   0           ['concatenate_40[0][0]',
#                                                                   'conv2d_43[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 42)  168         ['concatenate_41[0][0]']
#  ormalization)
#
#  re_lu_43 (ReLU)                (None, 16, 16, 42)   0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 6)    2274        ['re_lu_43[0][0]']
#
#  concatenate_42 (Concatenate)   (None, 16, 16, 48)   0           ['concatenate_41[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 16, 16, 48)  192         ['concatenate_42[0][0]']
#  ormalization)
#
#  re_lu_44 (ReLU)                (None, 16, 16, 48)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 6)    2598        ['re_lu_44[0][0]']
#
#  concatenate_43 (Concatenate)   (None, 16, 16, 54)   0           ['concatenate_42[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 16, 16, 54)  216         ['concatenate_43[0][0]']
#  ormalization)
#
#  re_lu_45 (ReLU)                (None, 16, 16, 54)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 6)    2922        ['re_lu_45[0][0]']
#
#  concatenate_44 (Concatenate)   (None, 16, 16, 60)   0           ['concatenate_43[0][0]',
#                                                                   'conv2d_46[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 16, 16, 60)  240         ['concatenate_44[0][0]']
#  ormalization)
#
#  re_lu_46 (ReLU)                (None, 16, 16, 60)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 6)    3246        ['re_lu_46[0][0]']
#
#  concatenate_45 (Concatenate)   (None, 16, 16, 66)   0           ['concatenate_44[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 16, 16, 66)  264         ['concatenate_45[0][0]']
#  ormalization)
#
#  re_lu_47 (ReLU)                (None, 16, 16, 66)   0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 6)    3570        ['re_lu_47[0][0]']
#
# ...
#
#  conv2d_133 (Conv2D)            (None, 4, 4, 6)      7134        ['re_lu_132[0][0]']
#
#  concatenate_129 (Concatenate)  (None, 4, 4, 138)    0           ['concatenate_128[0][0]',
#                                                                   'conv2d_133[0][0]']
#
#  batch_normalization_133 (Batch  (None, 4, 4, 138)   552         ['concatenate_129[0][0]']
#  Normalization)
#
#  re_lu_133 (ReLU)               (None, 4, 4, 138)    0           ['batch_normalization_133[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 4, 4, 6)      7458        ['re_lu_133[0][0]']
#
#  concatenate_130 (Concatenate)  (None, 4, 4, 144)    0           ['concatenate_129[0][0]',
#                                                                   'conv2d_134[0][0]']
#
#  batch_normalization_134 (Batch  (None, 4, 4, 144)   576         ['concatenate_130[0][0]']
#  Normalization)
#
#  re_lu_134 (ReLU)               (None, 4, 4, 144)    0           ['batch_normalization_134[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 4, 4, 6)      7782        ['re_lu_134[0][0]']
#
#  concatenate_131 (Concatenate)  (None, 4, 4, 150)    0           ['concatenate_130[0][0]',
#                                                                   'conv2d_135[0][0]']
#
#  batch_normalization_135 (Batch  (None, 4, 4, 150)   600         ['concatenate_131[0][0]']
#  Normalization)
#
#  re_lu_135 (ReLU)               (None, 4, 4, 150)    0           ['batch_normalization_135[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 4, 4, 6)      8106        ['re_lu_135[0][0]']
#
#  concatenate_132 (Concatenate)  (None, 4, 4, 156)    0           ['concatenate_131[0][0]',
#                                                                   'conv2d_136[0][0]']
#
#  batch_normalization_136 (Batch  (None, 4, 4, 156)   624         ['concatenate_132[0][0]']
#  Normalization)
#
#  re_lu_136 (ReLU)               (None, 4, 4, 156)    0           ['batch_normalization_136[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 4, 4, 6)      8430        ['re_lu_136[0][0]']
#
#  concatenate_133 (Concatenate)  (None, 4, 4, 162)    0           ['concatenate_132[0][0]',
#                                                                   'conv2d_137[0][0]']
#
#  batch_normalization_137 (Batch  (None, 4, 4, 162)   648         ['concatenate_133[0][0]']
#  Normalization)
#
#  re_lu_137 (ReLU)               (None, 4, 4, 162)    0           ['batch_normalization_137[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 4, 4, 6)      8754        ['re_lu_137[0][0]']
#
#  concatenate_134 (Concatenate)  (None, 4, 4, 168)    0           ['concatenate_133[0][0]',
#                                                                   'conv2d_138[0][0]']
#
#  batch_normalization_138 (Batch  (None, 4, 4, 168)   672         ['concatenate_134[0][0]']
#  Normalization)
#
#  re_lu_138 (ReLU)               (None, 4, 4, 168)    0           ['batch_normalization_138[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 4, 4, 6)      9078        ['re_lu_138[0][0]']
#
#  concatenate_135 (Concatenate)  (None, 4, 4, 174)    0           ['concatenate_134[0][0]',
#                                                                   'conv2d_139[0][0]']
#
#  batch_normalization_139 (Batch  (None, 4, 4, 174)   696         ['concatenate_135[0][0]']
#  Normalization)
#
#  re_lu_139 (ReLU)               (None, 4, 4, 174)    0           ['batch_normalization_139[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 4, 4, 6)      9402        ['re_lu_139[0][0]']
#
#  concatenate_136 (Concatenate)  (None, 4, 4, 180)    0           ['concatenate_135[0][0]',
#                                                                   'conv2d_140[0][0]']
#
#  batch_normalization_140 (Batch  (None, 4, 4, 180)   720         ['concatenate_136[0][0]']
#  Normalization)
#
#  re_lu_140 (ReLU)               (None, 4, 4, 180)    0           ['batch_normalization_140[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 4, 4, 6)      9726        ['re_lu_140[0][0]']
#
#  concatenate_137 (Concatenate)  (None, 4, 4, 186)    0           ['concatenate_136[0][0]',
#                                                                   'conv2d_141[0][0]']
#
#  batch_normalization_141 (Batch  (None, 4, 4, 186)   744         ['concatenate_137[0][0]']
#  Normalization)
#
#  re_lu_141 (ReLU)               (None, 4, 4, 186)    0           ['batch_normalization_141[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 4, 4, 6)      10050       ['re_lu_141[0][0]']
#
#  concatenate_138 (Concatenate)  (None, 4, 4, 192)    0           ['concatenate_137[0][0]',
#                                                                   'conv2d_142[0][0]']
#
#  batch_normalization_142 (Batch  (None, 4, 4, 192)   768         ['concatenate_138[0][0]']
#  Normalization)
#
#  re_lu_142 (ReLU)               (None, 4, 4, 192)    0           ['batch_normalization_142[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 4, 4, 6)      10374       ['re_lu_142[0][0]']
#
#  concatenate_139 (Concatenate)  (None, 4, 4, 198)    0           ['concatenate_138[0][0]',
#                                                                   'conv2d_143[0][0]']
#
#  batch_normalization_143 (Batch  (None, 4, 4, 198)   792         ['concatenate_139[0][0]']
#  Normalization)
#
#  re_lu_143 (ReLU)               (None, 4, 4, 198)    0           ['batch_normalization_143[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 4, 4, 6)      10698       ['re_lu_143[0][0]']
#
#  concatenate_140 (Concatenate)  (None, 4, 4, 204)    0           ['concatenate_139[0][0]',
#                                                                   'conv2d_144[0][0]']
#
#  batch_normalization_144 (Batch  (None, 4, 4, 204)   816         ['concatenate_140[0][0]']
#  Normalization)
#
#  re_lu_144 (ReLU)               (None, 4, 4, 204)    0           ['batch_normalization_144[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 4, 4, 6)      11022       ['re_lu_144[0][0]']
#
#  concatenate_141 (Concatenate)  (None, 4, 4, 210)    0           ['concatenate_140[0][0]',
#                                                                   'conv2d_145[0][0]']
#
#  batch_normalization_145 (Batch  (None, 4, 4, 210)   840         ['concatenate_141[0][0]']
#  Normalization)
#
#  re_lu_145 (ReLU)               (None, 4, 4, 210)    0           ['batch_normalization_145[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 4, 4, 6)      11346       ['re_lu_145[0][0]']
#
#  concatenate_142 (Concatenate)  (None, 4, 4, 216)    0           ['concatenate_141[0][0]',
#                                                                   'conv2d_146[0][0]']
#
#  batch_normalization_146 (Batch  (None, 4, 4, 216)   864         ['concatenate_142[0][0]']
#  Normalization)
#
#  re_lu_146 (ReLU)               (None, 4, 4, 216)    0           ['batch_normalization_146[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 4, 4, 6)      11670       ['re_lu_146[0][0]']
#
#  concatenate_143 (Concatenate)  (None, 4, 4, 222)    0           ['concatenate_142[0][0]',
#                                                                   'conv2d_147[0][0]']
#
#  batch_normalization_147 (Batch  (None, 4, 4, 222)   888         ['concatenate_143[0][0]']
#  Normalization)
#
#  re_lu_147 (ReLU)               (None, 4, 4, 222)    0           ['batch_normalization_147[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 2, 2, 222)   0           ['re_lu_147[0][0]']
#  oling2D)
#
#  flatten (Flatten)              (None, 888)          0           ['average_pooling2d_3[0][0]']
#
#  dense (Dense)                  (None, 10)           8890        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 969,400
# Trainable params: 935,212
# Non-trainable params: 34,188
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %%
filepath = "model_save/best_model.h5"
model_save_callback = ModelCheckpoint(filepath=filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# early_stop_callback = EarlyStopping(monitor='val_accuracy', min_delta=0.05, patience=10, verbose=1)

log_dir = os.path.join('logs', 'fits', datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

callbacks = [model_save_callback, tensorboard_callback]

# %%
model.fit(x=X_train_image_generator,
          batch_size=128,
          epochs=300,
          verbose=1,
          validation_data=X_test_image_generator,
          callbacks=callbacks)
# Out:
# Epoch 1/300
# 1563/1563 [==============================] - ETA: 0s - loss: 1.6477 - accuracy: 0.3936
# Epoch 1: val_accuracy improved from -inf to 0.46000, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 166s 89ms/step - loss: 1.6477 - accuracy: 0.3936 - val_loss: 1.5638 - val_accuracy: 0.4600
# Epoch 2/300
# 1563/1563 [==============================] - ETA: 0s - loss: 1.2639 - accuracy: 0.5406
# Epoch 2: val_accuracy improved from 0.46000 to 0.56380, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 133s 85ms/step - loss: 1.2639 - accuracy: 0.5406 - val_loss: 1.2253 - val_accuracy: 0.5638
# Epoch 3/300
# 1563/1563 [==============================] - ETA: 0s - loss: 1.0745 - accuracy: 0.6153
# Epoch 3: val_accuracy improved from 0.56380 to 0.62070, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 135s 86ms/step - loss: 1.0745 - accuracy: 0.6153 - val_loss: 1.0596 - val_accuracy: 0.6207
# Epoch 4/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.9412 - accuracy: 0.6665
# Epoch 4: val_accuracy did not improve from 0.62070
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.9412 - accuracy: 0.6665 - val_loss: 1.0903 - val_accuracy: 0.6151
# Epoch 5/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.8595 - accuracy: 0.6974
# Epoch 5: val_accuracy improved from 0.62070 to 0.64790, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.8595 - accuracy: 0.6974 - val_loss: 1.0027 - val_accuracy: 0.6479
# Epoch 6/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.7865 - accuracy: 0.7238
# Epoch 6: val_accuracy improved from 0.64790 to 0.70680, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.7865 - accuracy: 0.7238 - val_loss: 0.8520 - val_accuracy: 0.7068
# Epoch 7/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.7314 - accuracy: 0.7445
# Epoch 7: val_accuracy did not improve from 0.70680
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.7314 - accuracy: 0.7445 - val_loss: 0.9490 - val_accuracy: 0.6757
# Epoch 8/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6843 - accuracy: 0.7621
# Epoch 8: val_accuracy did not improve from 0.70680
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.6843 - accuracy: 0.7621 - val_loss: 0.9282 - val_accuracy: 0.6806
# Epoch 9/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6509 - accuracy: 0.7745
# Epoch 9: val_accuracy improved from 0.70680 to 0.75930, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.6509 - accuracy: 0.7745 - val_loss: 0.7003 - val_accuracy: 0.7593
# Epoch 10/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6118 - accuracy: 0.7868
# Epoch 10: val_accuracy did not improve from 0.75930
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.6118 - accuracy: 0.7868 - val_loss: 0.6995 - val_accuracy: 0.7588
# Epoch 11/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5836 - accuracy: 0.7963
# Epoch 11: val_accuracy improved from 0.75930 to 0.78110, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.5836 - accuracy: 0.7963 - val_loss: 0.6384 - val_accuracy: 0.7811
# Epoch 12/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5609 - accuracy: 0.8046
# Epoch 12: val_accuracy did not improve from 0.78110
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.5609 - accuracy: 0.8046 - val_loss: 0.7117 - val_accuracy: 0.7555
# Epoch 13/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5348 - accuracy: 0.8139
# Epoch 13: val_accuracy improved from 0.78110 to 0.80350, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.5348 - accuracy: 0.8139 - val_loss: 0.5855 - val_accuracy: 0.8035
# Epoch 14/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5129 - accuracy: 0.8220
# Epoch 14: val_accuracy did not improve from 0.80350
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.5129 - accuracy: 0.8220 - val_loss: 0.5751 - val_accuracy: 0.8023
# Epoch 15/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4911 - accuracy: 0.8295
# Epoch 15: val_accuracy did not improve from 0.80350
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.4911 - accuracy: 0.8295 - val_loss: 0.6201 - val_accuracy: 0.7854
# Epoch 16/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4754 - accuracy: 0.8350
# Epoch 16: val_accuracy did not improve from 0.80350
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.4754 - accuracy: 0.8350 - val_loss: 0.6138 - val_accuracy: 0.7914
# Epoch 17/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4603 - accuracy: 0.8394
# Epoch 17: val_accuracy improved from 0.80350 to 0.81790, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.4603 - accuracy: 0.8394 - val_loss: 0.5326 - val_accuracy: 0.8179
# Epoch 18/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4424 - accuracy: 0.8465
# Epoch 18: val_accuracy did not improve from 0.81790
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.4424 - accuracy: 0.8465 - val_loss: 0.5432 - val_accuracy: 0.8150
# Epoch 19/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4287 - accuracy: 0.8517
# Epoch 19: val_accuracy did not improve from 0.81790
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.4287 - accuracy: 0.8517 - val_loss: 0.5778 - val_accuracy: 0.8008
# Epoch 20/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4198 - accuracy: 0.8547
# Epoch 20: val_accuracy improved from 0.81790 to 0.82330, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.4198 - accuracy: 0.8547 - val_loss: 0.5152 - val_accuracy: 0.8233
# Epoch 21/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4061 - accuracy: 0.8594
# Epoch 21: val_accuracy did not improve from 0.82330
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.4061 - accuracy: 0.8594 - val_loss: 0.5562 - val_accuracy: 0.8109
# Epoch 22/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3941 - accuracy: 0.8638
# Epoch 22: val_accuracy did not improve from 0.82330
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.3941 - accuracy: 0.8638 - val_loss: 0.6016 - val_accuracy: 0.8062
# Epoch 23/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3836 - accuracy: 0.8665
# Epoch 23: val_accuracy improved from 0.82330 to 0.83570, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.3836 - accuracy: 0.8665 - val_loss: 0.4792 - val_accuracy: 0.8357
# Epoch 24/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3730 - accuracy: 0.8710
# Epoch 24: val_accuracy improved from 0.83570 to 0.83890, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.3730 - accuracy: 0.8710 - val_loss: 0.4786 - val_accuracy: 0.8389
# Epoch 25/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3654 - accuracy: 0.8734
# Epoch 25: val_accuracy did not improve from 0.83890
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.3654 - accuracy: 0.8734 - val_loss: 0.5169 - val_accuracy: 0.8268
# Epoch 26/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3576 - accuracy: 0.8752
# Epoch 26: val_accuracy did not improve from 0.83890
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.3576 - accuracy: 0.8752 - val_loss: 0.5051 - val_accuracy: 0.8329
# Epoch 27/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3468 - accuracy: 0.8803
# Epoch 27: val_accuracy did not improve from 0.83890
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.3468 - accuracy: 0.8803 - val_loss: 0.5196 - val_accuracy: 0.8175
# Epoch 28/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3389 - accuracy: 0.8804
# Epoch 28: val_accuracy did not improve from 0.83890
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.3389 - accuracy: 0.8804 - val_loss: 0.5074 - val_accuracy: 0.8323
# Epoch 29/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3305 - accuracy: 0.8853
# Epoch 29: val_accuracy improved from 0.83890 to 0.85260, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.3305 - accuracy: 0.8853 - val_loss: 0.4424 - val_accuracy: 0.8526
# Epoch 30/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3240 - accuracy: 0.8867
# Epoch 30: val_accuracy did not improve from 0.85260
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.3240 - accuracy: 0.8867 - val_loss: 0.6009 - val_accuracy: 0.8044
# Epoch 31/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.8895
# Epoch 31: val_accuracy improved from 0.85260 to 0.85410, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.3157 - accuracy: 0.8895 - val_loss: 0.4244 - val_accuracy: 0.8541
# Epoch 32/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3089 - accuracy: 0.8923
# Epoch 32: val_accuracy did not improve from 0.85410
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.3089 - accuracy: 0.8923 - val_loss: 0.5304 - val_accuracy: 0.8255
# Epoch 33/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3050 - accuracy: 0.8925
# Epoch 33: val_accuracy improved from 0.85410 to 0.86320, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.3050 - accuracy: 0.8925 - val_loss: 0.4106 - val_accuracy: 0.8632
# Epoch 34/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2974 - accuracy: 0.8971
# Epoch 34: val_accuracy improved from 0.86320 to 0.86600, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.2974 - accuracy: 0.8971 - val_loss: 0.4109 - val_accuracy: 0.8660
# Epoch 35/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2910 - accuracy: 0.8976
# Epoch 35: val_accuracy did not improve from 0.86600
# 1563/1563 [==============================] - 134s 85ms/step - loss: 0.2910 - accuracy: 0.8976 - val_loss: 0.4178 - val_accuracy: 0.8565
# Epoch 36/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2859 - accuracy: 0.8993
# Epoch 36: val_accuracy did not improve from 0.86600
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.2859 - accuracy: 0.8993 - val_loss: 0.4213 - val_accuracy: 0.8584
# Epoch 37/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2797 - accuracy: 0.9031
# Epoch 37: val_accuracy did not improve from 0.86600
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.2797 - accuracy: 0.9031 - val_loss: 0.4501 - val_accuracy: 0.8513
# Epoch 38/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2681 - accuracy: 0.9064
# Epoch 38: val_accuracy did not improve from 0.86600
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.2681 - accuracy: 0.9064 - val_loss: 0.4318 - val_accuracy: 0.8583
# Epoch 39/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2685 - accuracy: 0.9055
# Epoch 39: val_accuracy did not improve from 0.86600
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.2685 - accuracy: 0.9055 - val_loss: 0.5006 - val_accuracy: 0.8409
# Epoch 40/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2642 - accuracy: 0.9061
# Epoch 40: val_accuracy did not improve from 0.86600
# 1563/1563 [==============================] - 139s 89ms/step - loss: 0.2642 - accuracy: 0.9061 - val_loss: 0.4173 - val_accuracy: 0.8655
# Epoch 41/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2613 - accuracy: 0.9086
# Epoch 41: val_accuracy did not improve from 0.86600
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.2613 - accuracy: 0.9086 - val_loss: 0.4899 - val_accuracy: 0.8460
# Epoch 42/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2559 - accuracy: 0.9091
# Epoch 42: val_accuracy improved from 0.86600 to 0.86790, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.2559 - accuracy: 0.9091 - val_loss: 0.4088 - val_accuracy: 0.8679
# Epoch 43/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2460 - accuracy: 0.9136
# Epoch 43: val_accuracy did not improve from 0.86790
# 1563/1563 [==============================] - 139s 89ms/step - loss: 0.2460 - accuracy: 0.9136 - val_loss: 0.4339 - val_accuracy: 0.8589
# Epoch 44/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2463 - accuracy: 0.9139
# Epoch 44: val_accuracy did not improve from 0.86790
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.2463 - accuracy: 0.9139 - val_loss: 0.4148 - val_accuracy: 0.8678
# Epoch 45/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2407 - accuracy: 0.9147
# Epoch 45: val_accuracy did not improve from 0.86790
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.2407 - accuracy: 0.9147 - val_loss: 0.4274 - val_accuracy: 0.8618
# Epoch 46/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.9168
# Epoch 46: val_accuracy did not improve from 0.86790
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.2384 - accuracy: 0.9168 - val_loss: 0.4167 - val_accuracy: 0.8650
# Epoch 47/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2312 - accuracy: 0.9188
# Epoch 47: val_accuracy did not improve from 0.86790
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.2312 - accuracy: 0.9188 - val_loss: 0.4394 - val_accuracy: 0.8574
# Epoch 48/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2305 - accuracy: 0.9198
# Epoch 48: val_accuracy did not improve from 0.86790
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.2305 - accuracy: 0.9198 - val_loss: 0.4144 - val_accuracy: 0.8667
# Epoch 49/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2274 - accuracy: 0.9200
# Epoch 49: val_accuracy did not improve from 0.86790
# 1563/1563 [==============================] - 140s 90ms/step - loss: 0.2274 - accuracy: 0.9200 - val_loss: 0.4230 - val_accuracy: 0.8639
# Epoch 50/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2203 - accuracy: 0.9233
# Epoch 50: val_accuracy did not improve from 0.86790
# 1563/1563 [==============================] - 140s 90ms/step - loss: 0.2203 - accuracy: 0.9233 - val_loss: 0.4111 - val_accuracy: 0.8668
# Epoch 51/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2179 - accuracy: 0.9235
# Epoch 51: val_accuracy did not improve from 0.86790
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.2179 - accuracy: 0.9235 - val_loss: 0.4885 - val_accuracy: 0.8488
# Epoch 52/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9254
# Epoch 52: val_accuracy did not improve from 0.86790
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.2153 - accuracy: 0.9254 - val_loss: 0.4094 - val_accuracy: 0.8667
# Epoch 53/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9255
# Epoch 53: val_accuracy did not improve from 0.86790
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.2117 - accuracy: 0.9255 - val_loss: 0.4206 - val_accuracy: 0.8623
# Epoch 54/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2093 - accuracy: 0.9272
# Epoch 54: val_accuracy improved from 0.86790 to 0.87040, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.2093 - accuracy: 0.9272 - val_loss: 0.4006 - val_accuracy: 0.8704
# Epoch 55/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2053 - accuracy: 0.9267
# Epoch 55: val_accuracy improved from 0.87040 to 0.88380, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.2053 - accuracy: 0.9267 - val_loss: 0.3658 - val_accuracy: 0.8838
# Epoch 56/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2053 - accuracy: 0.9266
# Epoch 56: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.2053 - accuracy: 0.9266 - val_loss: 0.3943 - val_accuracy: 0.8753
# Epoch 57/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1997 - accuracy: 0.9292
# Epoch 57: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1997 - accuracy: 0.9292 - val_loss: 0.3977 - val_accuracy: 0.8741
# Epoch 58/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 0.9282
# Epoch 58: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1991 - accuracy: 0.9282 - val_loss: 0.4457 - val_accuracy: 0.8610
# Epoch 59/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1949 - accuracy: 0.9314
# Epoch 59: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1949 - accuracy: 0.9314 - val_loss: 0.4282 - val_accuracy: 0.8691
# Epoch 60/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1919 - accuracy: 0.9320
# Epoch 60: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1919 - accuracy: 0.9320 - val_loss: 0.3973 - val_accuracy: 0.8745
# Epoch 61/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9322
# Epoch 61: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1907 - accuracy: 0.9322 - val_loss: 0.4168 - val_accuracy: 0.8726
# Epoch 62/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1849 - accuracy: 0.9342
# Epoch 62: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1849 - accuracy: 0.9342 - val_loss: 0.3797 - val_accuracy: 0.8788
# Epoch 63/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9339
# Epoch 63: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1841 - accuracy: 0.9339 - val_loss: 0.4125 - val_accuracy: 0.8703
# Epoch 64/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1812 - accuracy: 0.9362
# Epoch 64: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1812 - accuracy: 0.9362 - val_loss: 0.4191 - val_accuracy: 0.8706
# Epoch 65/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1801 - accuracy: 0.9365
# Epoch 65: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1801 - accuracy: 0.9365 - val_loss: 0.3808 - val_accuracy: 0.8812
# Epoch 66/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1793 - accuracy: 0.9359
# Epoch 66: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1793 - accuracy: 0.9359 - val_loss: 0.4295 - val_accuracy: 0.8734
# Epoch 67/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1721 - accuracy: 0.9388
# Epoch 67: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1721 - accuracy: 0.9388 - val_loss: 0.4079 - val_accuracy: 0.8702
# Epoch 68/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1751 - accuracy: 0.9380
# Epoch 68: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1751 - accuracy: 0.9380 - val_loss: 0.4176 - val_accuracy: 0.8756
# Epoch 69/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1722 - accuracy: 0.9383
# Epoch 69: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1722 - accuracy: 0.9383 - val_loss: 0.3814 - val_accuracy: 0.8798
# Epoch 70/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1707 - accuracy: 0.9401
# Epoch 70: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1707 - accuracy: 0.9401 - val_loss: 0.4212 - val_accuracy: 0.8752
# Epoch 71/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1692 - accuracy: 0.9412
# Epoch 71: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1692 - accuracy: 0.9412 - val_loss: 0.4060 - val_accuracy: 0.8771
# Epoch 72/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9410
# Epoch 72: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1658 - accuracy: 0.9410 - val_loss: 0.4633 - val_accuracy: 0.8595
# Epoch 73/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9431
# Epoch 73: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.1609 - accuracy: 0.9431 - val_loss: 0.4085 - val_accuracy: 0.8723
# Epoch 74/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1630 - accuracy: 0.9424
# Epoch 74: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.1630 - accuracy: 0.9424 - val_loss: 0.3967 - val_accuracy: 0.8800
# Epoch 75/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1597 - accuracy: 0.9432
# Epoch 75: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1597 - accuracy: 0.9432 - val_loss: 0.4384 - val_accuracy: 0.8691
# Epoch 76/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1581 - accuracy: 0.9440
# Epoch 76: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1581 - accuracy: 0.9440 - val_loss: 0.4004 - val_accuracy: 0.8767
# Epoch 77/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9449
# Epoch 77: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1580 - accuracy: 0.9449 - val_loss: 0.3957 - val_accuracy: 0.8793
# Epoch 78/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1536 - accuracy: 0.9461
# Epoch 78: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.1536 - accuracy: 0.9461 - val_loss: 0.4056 - val_accuracy: 0.8777
# Epoch 79/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1524 - accuracy: 0.9466
# Epoch 79: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1524 - accuracy: 0.9466 - val_loss: 0.4447 - val_accuracy: 0.8701
# Epoch 80/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9458
# Epoch 80: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1530 - accuracy: 0.9458 - val_loss: 0.4147 - val_accuracy: 0.8776
# Epoch 81/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1502 - accuracy: 0.9477
# Epoch 81: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.1502 - accuracy: 0.9477 - val_loss: 0.3869 - val_accuracy: 0.8805
# Epoch 82/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1488 - accuracy: 0.9476
# Epoch 82: val_accuracy did not improve from 0.88380
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1488 - accuracy: 0.9476 - val_loss: 0.4063 - val_accuracy: 0.8807
# Epoch 83/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 0.9489
# Epoch 83: val_accuracy improved from 0.88380 to 0.88470, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.1428 - accuracy: 0.9489 - val_loss: 0.3987 - val_accuracy: 0.8847
# Epoch 84/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1418 - accuracy: 0.9493
# Epoch 84: val_accuracy did not improve from 0.88470
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.1418 - accuracy: 0.9493 - val_loss: 0.3999 - val_accuracy: 0.8794
# Epoch 85/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1479 - accuracy: 0.9466
# Epoch 85: val_accuracy did not improve from 0.88470
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1479 - accuracy: 0.9466 - val_loss: 0.4058 - val_accuracy: 0.8806
# Epoch 86/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.9487
# Epoch 86: val_accuracy did not improve from 0.88470
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1453 - accuracy: 0.9487 - val_loss: 0.4142 - val_accuracy: 0.8792
# Epoch 87/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1391 - accuracy: 0.9503
# Epoch 87: val_accuracy did not improve from 0.88470
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1391 - accuracy: 0.9503 - val_loss: 0.4265 - val_accuracy: 0.8766
# Epoch 88/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1389 - accuracy: 0.9518
# Epoch 88: val_accuracy improved from 0.88470 to 0.88620, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.1389 - accuracy: 0.9518 - val_loss: 0.3905 - val_accuracy: 0.8862
# Epoch 89/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1393 - accuracy: 0.9496
# Epoch 89: val_accuracy did not improve from 0.88620
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1393 - accuracy: 0.9496 - val_loss: 0.4007 - val_accuracy: 0.8802
# Epoch 90/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9509
# Epoch 90: val_accuracy did not improve from 0.88620
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1401 - accuracy: 0.9509 - val_loss: 0.3883 - val_accuracy: 0.8824
# Epoch 91/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9520
# Epoch 91: val_accuracy improved from 0.88620 to 0.88860, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.1363 - accuracy: 0.9520 - val_loss: 0.3774 - val_accuracy: 0.8886
# Epoch 92/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9520
# Epoch 92: val_accuracy did not improve from 0.88860
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1347 - accuracy: 0.9520 - val_loss: 0.3796 - val_accuracy: 0.8870
# Epoch 93/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1359 - accuracy: 0.9516
# Epoch 93: val_accuracy improved from 0.88860 to 0.88920, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.1359 - accuracy: 0.9516 - val_loss: 0.3702 - val_accuracy: 0.8892
# Epoch 94/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9527
# Epoch 94: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1341 - accuracy: 0.9527 - val_loss: 0.4199 - val_accuracy: 0.8810
# Epoch 95/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1312 - accuracy: 0.9540
# Epoch 95: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.1312 - accuracy: 0.9540 - val_loss: 0.4097 - val_accuracy: 0.8803
# Epoch 96/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9545
# Epoch 96: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.1269 - accuracy: 0.9545 - val_loss: 0.4213 - val_accuracy: 0.8802
# Epoch 97/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9547
# Epoch 97: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1304 - accuracy: 0.9547 - val_loss: 0.4221 - val_accuracy: 0.8780
# Epoch 98/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1284 - accuracy: 0.9538
# Epoch 98: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1284 - accuracy: 0.9538 - val_loss: 0.4228 - val_accuracy: 0.8763
# Epoch 99/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9554
# Epoch 99: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.1269 - accuracy: 0.9554 - val_loss: 0.3769 - val_accuracy: 0.8835
# Epoch 100/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1247 - accuracy: 0.9560
# Epoch 100: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 140s 90ms/step - loss: 0.1247 - accuracy: 0.9560 - val_loss: 0.4162 - val_accuracy: 0.8794
# Epoch 101/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1259 - accuracy: 0.9555
# Epoch 101: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1259 - accuracy: 0.9555 - val_loss: 0.4346 - val_accuracy: 0.8744
# Epoch 102/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9555
# Epoch 102: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.1244 - accuracy: 0.9555 - val_loss: 0.4224 - val_accuracy: 0.8817
# Epoch 103/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.9566
# Epoch 103: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1221 - accuracy: 0.9566 - val_loss: 0.4122 - val_accuracy: 0.8866
# Epoch 104/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1203 - accuracy: 0.9561
# Epoch 104: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.1203 - accuracy: 0.9561 - val_loss: 0.4114 - val_accuracy: 0.8838
# Epoch 105/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9565
# Epoch 105: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1207 - accuracy: 0.9565 - val_loss: 0.4054 - val_accuracy: 0.8810
# Epoch 106/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9583
# Epoch 106: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.1192 - accuracy: 0.9583 - val_loss: 0.4343 - val_accuracy: 0.8760
# Epoch 107/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1175 - accuracy: 0.9581
# Epoch 107: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1175 - accuracy: 0.9581 - val_loss: 0.4117 - val_accuracy: 0.8888
# Epoch 108/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9579
# Epoch 108: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1192 - accuracy: 0.9579 - val_loss: 0.3917 - val_accuracy: 0.8876
# Epoch 109/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1124 - accuracy: 0.9603
# Epoch 109: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1124 - accuracy: 0.9603 - val_loss: 0.3993 - val_accuracy: 0.8864
# Epoch 110/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1133 - accuracy: 0.9586
# Epoch 110: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1133 - accuracy: 0.9586 - val_loss: 0.4525 - val_accuracy: 0.8728
# Epoch 111/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9601
# Epoch 111: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.1125 - accuracy: 0.9601 - val_loss: 0.4100 - val_accuracy: 0.8883
# Epoch 112/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1118 - accuracy: 0.9604
# Epoch 112: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1118 - accuracy: 0.9604 - val_loss: 0.4076 - val_accuracy: 0.8867
# Epoch 113/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9603
# Epoch 113: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.1119 - accuracy: 0.9603 - val_loss: 0.4233 - val_accuracy: 0.8826
# Epoch 114/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.9587
# Epoch 114: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.1154 - accuracy: 0.9587 - val_loss: 0.4021 - val_accuracy: 0.8849
# Epoch 115/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1087 - accuracy: 0.9613
# Epoch 115: val_accuracy did not improve from 0.88920
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.1087 - accuracy: 0.9613 - val_loss: 0.4616 - val_accuracy: 0.8791
# Epoch 116/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1096 - accuracy: 0.9615
# Epoch 116: val_accuracy improved from 0.88920 to 0.89050, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.1096 - accuracy: 0.9615 - val_loss: 0.4088 - val_accuracy: 0.8905
# Epoch 117/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1096 - accuracy: 0.9611
# Epoch 117: val_accuracy did not improve from 0.89050
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1096 - accuracy: 0.9611 - val_loss: 0.3942 - val_accuracy: 0.8892
# Epoch 118/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9602
# Epoch 118: val_accuracy improved from 0.89050 to 0.89120, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.1112 - accuracy: 0.9602 - val_loss: 0.3743 - val_accuracy: 0.8912
# Epoch 119/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9620
# Epoch 119: val_accuracy did not improve from 0.89120
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1071 - accuracy: 0.9620 - val_loss: 0.4130 - val_accuracy: 0.8864
# Epoch 120/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9604
# Epoch 120: val_accuracy did not improve from 0.89120
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1083 - accuracy: 0.9604 - val_loss: 0.4201 - val_accuracy: 0.8850
# Epoch 121/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9615
# Epoch 121: val_accuracy did not improve from 0.89120
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1066 - accuracy: 0.9615 - val_loss: 0.3946 - val_accuracy: 0.8912
# Epoch 122/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.9625
# Epoch 122: val_accuracy did not improve from 0.89120
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.1053 - accuracy: 0.9625 - val_loss: 0.4342 - val_accuracy: 0.8873
# Epoch 123/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.9621
# Epoch 123: val_accuracy improved from 0.89120 to 0.89260, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.1057 - accuracy: 0.9621 - val_loss: 0.3768 - val_accuracy: 0.8926
# Epoch 124/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1038 - accuracy: 0.9634
# Epoch 124: val_accuracy did not improve from 0.89260
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.1038 - accuracy: 0.9634 - val_loss: 0.4347 - val_accuracy: 0.8857
# Epoch 125/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1036 - accuracy: 0.9622
# Epoch 125: val_accuracy did not improve from 0.89260
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1036 - accuracy: 0.9622 - val_loss: 0.3844 - val_accuracy: 0.8924
# Epoch 126/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9612
# Epoch 126: val_accuracy improved from 0.89260 to 0.89310, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.1072 - accuracy: 0.9612 - val_loss: 0.4034 - val_accuracy: 0.8931
# Epoch 127/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9638
# Epoch 127: val_accuracy did not improve from 0.89310
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1018 - accuracy: 0.9638 - val_loss: 0.4217 - val_accuracy: 0.8861
# Epoch 128/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9642
# Epoch 128: val_accuracy did not improve from 0.89310
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.0997 - accuracy: 0.9642 - val_loss: 0.3965 - val_accuracy: 0.8920
# Epoch 129/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1022 - accuracy: 0.9633
# Epoch 129: val_accuracy did not improve from 0.89310
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1022 - accuracy: 0.9633 - val_loss: 0.4220 - val_accuracy: 0.8864
# Epoch 130/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0977 - accuracy: 0.9660
# Epoch 130: val_accuracy did not improve from 0.89310
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0977 - accuracy: 0.9660 - val_loss: 0.4199 - val_accuracy: 0.8889
# Epoch 131/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9645
# Epoch 131: val_accuracy did not improve from 0.89310
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1013 - accuracy: 0.9645 - val_loss: 0.4074 - val_accuracy: 0.8886
# Epoch 132/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.9661
# Epoch 132: val_accuracy did not improve from 0.89310
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.0965 - accuracy: 0.9661 - val_loss: 0.4226 - val_accuracy: 0.8873
# Epoch 133/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9643
# Epoch 133: val_accuracy did not improve from 0.89310
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1008 - accuracy: 0.9643 - val_loss: 0.4222 - val_accuracy: 0.8905
# Epoch 134/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.9646
# Epoch 134: val_accuracy did not improve from 0.89310
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.1012 - accuracy: 0.9646 - val_loss: 0.3999 - val_accuracy: 0.8916
# Epoch 135/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0948 - accuracy: 0.9670
# Epoch 135: val_accuracy improved from 0.89310 to 0.89380, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0948 - accuracy: 0.9670 - val_loss: 0.3875 - val_accuracy: 0.8938
# Epoch 136/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0983 - accuracy: 0.9653
# Epoch 136: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.0983 - accuracy: 0.9653 - val_loss: 0.4078 - val_accuracy: 0.8877
# Epoch 137/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9669
# Epoch 137: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0958 - accuracy: 0.9669 - val_loss: 0.4082 - val_accuracy: 0.8896
# Epoch 138/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9672
# Epoch 138: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.0928 - accuracy: 0.9672 - val_loss: 0.4432 - val_accuracy: 0.8856
# Epoch 139/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.9668
# Epoch 139: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.0914 - accuracy: 0.9668 - val_loss: 0.4320 - val_accuracy: 0.8838
# Epoch 140/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9673
# Epoch 140: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0918 - accuracy: 0.9673 - val_loss: 0.4120 - val_accuracy: 0.8893
# Epoch 141/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0966 - accuracy: 0.9654
# Epoch 141: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0966 - accuracy: 0.9654 - val_loss: 0.4157 - val_accuracy: 0.8928
# Epoch 142/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0943 - accuracy: 0.9674
# Epoch 142: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0943 - accuracy: 0.9674 - val_loss: 0.4260 - val_accuracy: 0.8884
# Epoch 143/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0904 - accuracy: 0.9679
# Epoch 143: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0904 - accuracy: 0.9679 - val_loss: 0.4158 - val_accuracy: 0.8896
# Epoch 144/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0913 - accuracy: 0.9683
# Epoch 144: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0913 - accuracy: 0.9683 - val_loss: 0.4280 - val_accuracy: 0.8873
# Epoch 145/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9685
# Epoch 145: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.0910 - accuracy: 0.9685 - val_loss: 0.4266 - val_accuracy: 0.8886
# Epoch 146/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0895 - accuracy: 0.9682
# Epoch 146: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.0895 - accuracy: 0.9682 - val_loss: 0.4076 - val_accuracy: 0.8910
# Epoch 147/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0896 - accuracy: 0.9682
# Epoch 147: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.0896 - accuracy: 0.9682 - val_loss: 0.4252 - val_accuracy: 0.8900
# Epoch 148/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 0.9678
# Epoch 148: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.0903 - accuracy: 0.9678 - val_loss: 0.4423 - val_accuracy: 0.8841
# Epoch 149/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9684
# Epoch 149: val_accuracy did not improve from 0.89380
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.0909 - accuracy: 0.9684 - val_loss: 0.4372 - val_accuracy: 0.8880
# Epoch 150/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9675
# Epoch 150: val_accuracy improved from 0.89380 to 0.89460, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 144s 92ms/step - loss: 0.0918 - accuracy: 0.9675 - val_loss: 0.3979 - val_accuracy: 0.8946
# Epoch 151/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9688
# Epoch 151: val_accuracy did not improve from 0.89460
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.0889 - accuracy: 0.9688 - val_loss: 0.4200 - val_accuracy: 0.8876
# Epoch 152/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9693
# Epoch 152: val_accuracy improved from 0.89460 to 0.89690, saving model to model_save/best_model.h5
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.0862 - accuracy: 0.9693 - val_loss: 0.3915 - val_accuracy: 0.8969
# Epoch 153/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9693
# Epoch 153: val_accuracy did not improve from 0.89690
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.0870 - accuracy: 0.9693 - val_loss: 0.4707 - val_accuracy: 0.8853
# Epoch 154/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9708
# Epoch 154: val_accuracy did not improve from 0.89690
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0823 - accuracy: 0.9708 - val_loss: 0.4302 - val_accuracy: 0.8912
# Epoch 155/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9698
# Epoch 155: val_accuracy did not improve from 0.89690
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0859 - accuracy: 0.9698 - val_loss: 0.4273 - val_accuracy: 0.8942
# Epoch 156/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9687
# Epoch 156: val_accuracy did not improve from 0.89690
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0858 - accuracy: 0.9687 - val_loss: 0.4050 - val_accuracy: 0.8927
# Epoch 157/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0830 - accuracy: 0.9704
# Epoch 157: val_accuracy did not improve from 0.89690
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0830 - accuracy: 0.9704 - val_loss: 0.4058 - val_accuracy: 0.8933
# Epoch 158/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9693
# Epoch 158: val_accuracy did not improve from 0.89690
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.0858 - accuracy: 0.9693 - val_loss: 0.4358 - val_accuracy: 0.8871
# Epoch 159/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0827 - accuracy: 0.9719
# Epoch 159: val_accuracy did not improve from 0.89690
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0827 - accuracy: 0.9719 - val_loss: 0.4153 - val_accuracy: 0.8914
# Epoch 160/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0836 - accuracy: 0.9702
# Epoch 160: val_accuracy did not improve from 0.89690
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.0836 - accuracy: 0.9702 - val_loss: 0.4458 - val_accuracy: 0.8861
# Epoch 161/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.9707
# Epoch 161: val_accuracy did not improve from 0.89690
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.0829 - accuracy: 0.9707 - val_loss: 0.4317 - val_accuracy: 0.8901
# Epoch 162/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9707
# ...
# Epoch 246/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9790
# Epoch 246: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 137s 87ms/step - loss: 0.0587 - accuracy: 0.9790 - val_loss: 0.4790 - val_accuracy: 0.8886
# Epoch 247/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9805
# Epoch 247: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 137s 87ms/step - loss: 0.0562 - accuracy: 0.9805 - val_loss: 0.4141 - val_accuracy: 0.9015
# Epoch 248/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9798
# Epoch 248: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 137s 88ms/step - loss: 0.0574 - accuracy: 0.9798 - val_loss: 0.4527 - val_accuracy: 0.8945
# Epoch 249/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9811
# Epoch 249: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 137s 87ms/step - loss: 0.0538 - accuracy: 0.9811 - val_loss: 0.4834 - val_accuracy: 0.8911
# Epoch 250/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0590 - accuracy: 0.9794
# Epoch 250: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 137s 87ms/step - loss: 0.0590 - accuracy: 0.9794 - val_loss: 0.4266 - val_accuracy: 0.8989
# Epoch 251/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9800
# Epoch 251: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 137s 87ms/step - loss: 0.0572 - accuracy: 0.9800 - val_loss: 0.4177 - val_accuracy: 0.8988
# Epoch 252/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9807
# Epoch 252: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 136s 87ms/step - loss: 0.0559 - accuracy: 0.9807 - val_loss: 0.4442 - val_accuracy: 0.8941
# Epoch 253/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9801
# Epoch 253: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 137s 87ms/step - loss: 0.0567 - accuracy: 0.9801 - val_loss: 0.4688 - val_accuracy: 0.8952
# Epoch 254/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9797
# Epoch 254: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 136s 87ms/step - loss: 0.0583 - accuracy: 0.9797 - val_loss: 0.4569 - val_accuracy: 0.8918
# Epoch 255/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9805
# Epoch 255: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.0565 - accuracy: 0.9805 - val_loss: 0.4791 - val_accuracy: 0.8945
# Epoch 256/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9804
# Epoch 256: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.0548 - accuracy: 0.9804 - val_loss: 0.4599 - val_accuracy: 0.8944
# Epoch 257/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9796
# Epoch 257: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.0581 - accuracy: 0.9796 - val_loss: 0.4402 - val_accuracy: 0.8975
# Epoch 258/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9799
# Epoch 258: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.0569 - accuracy: 0.9799 - val_loss: 0.4556 - val_accuracy: 0.8940
# Epoch 259/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9805
# Epoch 259: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 137s 87ms/step - loss: 0.0550 - accuracy: 0.9805 - val_loss: 0.4163 - val_accuracy: 0.8958
# Epoch 260/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9800
# Epoch 260: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 137s 88ms/step - loss: 0.0568 - accuracy: 0.9800 - val_loss: 0.4532 - val_accuracy: 0.8960
# Epoch 261/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9806
# Epoch 261: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 137s 88ms/step - loss: 0.0554 - accuracy: 0.9806 - val_loss: 0.4918 - val_accuracy: 0.8899
# Epoch 262/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0558 - accuracy: 0.9806
# Epoch 262: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0558 - accuracy: 0.9806 - val_loss: 0.4314 - val_accuracy: 0.8949
# Epoch 263/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9809
# Epoch 263: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.0559 - accuracy: 0.9809 - val_loss: 0.4085 - val_accuracy: 0.9035
# Epoch 264/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9815
# Epoch 264: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.0519 - accuracy: 0.9815 - val_loss: 0.4691 - val_accuracy: 0.8946
# Epoch 265/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9803
# Epoch 265: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0572 - accuracy: 0.9803 - val_loss: 0.4487 - val_accuracy: 0.8948
# Epoch 266/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9807
# Epoch 266: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0562 - accuracy: 0.9807 - val_loss: 0.4387 - val_accuracy: 0.8978
# Epoch 267/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9827
# Epoch 267: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0518 - accuracy: 0.9827 - val_loss: 0.4339 - val_accuracy: 0.8972
# Epoch 268/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.9811
# Epoch 268: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.0536 - accuracy: 0.9811 - val_loss: 0.4649 - val_accuracy: 0.8930
# Epoch 269/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9817
# Epoch 269: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.0528 - accuracy: 0.9817 - val_loss: 0.4679 - val_accuracy: 0.8955
# Epoch 270/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9813
# Epoch 270: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.0545 - accuracy: 0.9813 - val_loss: 0.4589 - val_accuracy: 0.8954
# Epoch 271/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9806
# Epoch 271: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.0548 - accuracy: 0.9806 - val_loss: 0.4593 - val_accuracy: 0.8957
# Epoch 272/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9809
# Epoch 272: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0541 - accuracy: 0.9809 - val_loss: 0.4169 - val_accuracy: 0.9024
# Epoch 273/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9826
# Epoch 273: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.0506 - accuracy: 0.9826 - val_loss: 0.4461 - val_accuracy: 0.8988
# Epoch 274/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9811
# Epoch 274: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0545 - accuracy: 0.9811 - val_loss: 0.4582 - val_accuracy: 0.8963
# Epoch 275/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9815
# Epoch 275: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.0509 - accuracy: 0.9815 - val_loss: 0.4537 - val_accuracy: 0.8977
# Epoch 276/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9823
# Epoch 276: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.0510 - accuracy: 0.9823 - val_loss: 0.4457 - val_accuracy: 0.8989
# Epoch 277/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9810
# Epoch 277: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.0542 - accuracy: 0.9810 - val_loss: 0.4275 - val_accuracy: 0.8996
# Epoch 278/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9819
# Epoch 278: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 137s 88ms/step - loss: 0.0508 - accuracy: 0.9819 - val_loss: 0.4540 - val_accuracy: 0.8986
# Epoch 279/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0526 - accuracy: 0.9814
# Epoch 279: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 138s 88ms/step - loss: 0.0526 - accuracy: 0.9814 - val_loss: 0.4499 - val_accuracy: 0.8974
# Epoch 280/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9807
# Epoch 280: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 138s 88ms/step - loss: 0.0524 - accuracy: 0.9807 - val_loss: 0.4698 - val_accuracy: 0.8946
# Epoch 281/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9822
# Epoch 281: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 137s 87ms/step - loss: 0.0506 - accuracy: 0.9822 - val_loss: 0.4902 - val_accuracy: 0.8961
# Epoch 282/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0531 - accuracy: 0.9813
# Epoch 282: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.0531 - accuracy: 0.9813 - val_loss: 0.4195 - val_accuracy: 0.8991
# Epoch 283/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0477 - accuracy: 0.9836
# Epoch 283: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.0477 - accuracy: 0.9836 - val_loss: 0.6135 - val_accuracy: 0.8703
# Epoch 284/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9813
# Epoch 284: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.0529 - accuracy: 0.9813 - val_loss: 0.5118 - val_accuracy: 0.8871
# Epoch 285/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9822
# Epoch 285: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0509 - accuracy: 0.9822 - val_loss: 0.4675 - val_accuracy: 0.8906
# Epoch 286/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0514 - accuracy: 0.9823
# Epoch 286: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0514 - accuracy: 0.9823 - val_loss: 0.4374 - val_accuracy: 0.8998
# Epoch 287/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9823
# Epoch 287: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.0490 - accuracy: 0.9823 - val_loss: 0.4463 - val_accuracy: 0.8938
# Epoch 288/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9829
# Epoch 288: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.0489 - accuracy: 0.9829 - val_loss: 0.4652 - val_accuracy: 0.8986
# Epoch 289/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9824
# Epoch 289: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.0504 - accuracy: 0.9824 - val_loss: 0.5208 - val_accuracy: 0.8867
# Epoch 290/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9825
# Epoch 290: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0494 - accuracy: 0.9825 - val_loss: 0.4268 - val_accuracy: 0.9019
# Epoch 291/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9825
# Epoch 291: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.0502 - accuracy: 0.9825 - val_loss: 0.4464 - val_accuracy: 0.8987
# Epoch 292/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9822
# Epoch 292: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0509 - accuracy: 0.9822 - val_loss: 0.4483 - val_accuracy: 0.9006
# Epoch 293/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9820
# Epoch 293: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0502 - accuracy: 0.9820 - val_loss: 0.4370 - val_accuracy: 0.8994
# Epoch 294/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9822
# Epoch 294: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.0508 - accuracy: 0.9822 - val_loss: 0.4452 - val_accuracy: 0.8998
# Epoch 295/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9834
# Epoch 295: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 131s 84ms/step - loss: 0.0479 - accuracy: 0.9834 - val_loss: 0.4473 - val_accuracy: 0.8977
# Epoch 296/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9821
# Epoch 296: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0516 - accuracy: 0.9821 - val_loss: 0.4258 - val_accuracy: 0.9055
# Epoch 297/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9827
# Epoch 297: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.0490 - accuracy: 0.9827 - val_loss: 0.4180 - val_accuracy: 0.9002
# Epoch 298/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0482 - accuracy: 0.9825
# Epoch 298: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0482 - accuracy: 0.9825 - val_loss: 0.4632 - val_accuracy: 0.8968
# Epoch 299/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9827
# Epoch 299: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.0504 - accuracy: 0.9827 - val_loss: 0.4743 - val_accuracy: 0.8971
# Epoch 300/300
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9831
# Epoch 300: val_accuracy did not improve from 0.90560
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0495 - accuracy: 0.9831 - val_loss: 0.4283 - val_accuracy: 0.9052

# %%
model.load_weights(filepath=filepath)

# %%
test_loss, test_accuracy = model.evaluate(x=X_test_image_generator, verbose=1, batch_size=128)
# Out:
# 313/313 [==============================] - 8s 25ms/step - loss: 0.4084 - accuracy: 0.8977

# %%
print("Test Loss: {}.".format(test_loss))
print("Test Accuracy: {}.".format(test_accuracy * 100))
# Out:
# Test Loss: 0.40838003158569336.
# Test Accuracy: 89.77000117301941.

# %% [markdown]
# ### Please note, I spent more than 7000 INR to purchase compute resources, because I made a mistake in the image augmentation. The mistake was, I added more augmentations which eventually led to the poor performance of the model. I changed the filter values and retrained the model multiple times, which cost me. I am not worried about that.
#
# ### I realized lately that I need to reduce image augmentations in order to achieve the desired accuracy.
#
# ### Lesson: Just because image augmentations are cool, doesn't mean all augmentations need to be used in the problem.
#
# ### If you please notice, the best `val_accuracy` is about 90.56 and the `test_accuracy` is 89.77 which I think is acceptable.
#
# ### Please accept my efforts.
